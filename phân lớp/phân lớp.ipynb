# %%
from numpy import where
from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt

# %%
#phan lop nhi phan - 2 lop
x, y = make_blobs(n_samples = 1000, centers = 2, random_state = 1)
print(x.shape, y.shape) #chia x-input. y-output, x y random
# Out:
# (1000, 2) (1000,)

# %%
counter = Counter(y)
print(counter)  #kiem tra phan bo
# Out:
# Counter({0: 500, 1: 500})

# %%
for i in range(10):
    print(x[i], ',', y[i]) #10 gia tri dau
# Out:
# [-3.05837272  4.48825769] , 0
# [-8.60973869 -3.72714879] , 1
# [1.37129721 5.23107449] , 0
# [-9.33917563 -2.9544469 ] , 1
# [-11.57178593  -3.85275513] , 1
# [-11.42257341  -4.85679127] , 1
# [-10.44518578  -3.76476563] , 1
# [-10.44603561  -3.26065964] , 1
# [-0.61947075  3.48804983] , 0
# [-10.91115591  -4.5772537 ] , 1

# %%
for label, _ in counter.items():
    row_ix = where(y == label)[0]
    plt.scatter(x[row_ix,0], x[row_ix, 1], label = str(label))
plt.legend()
plt.show()

# %%
#phan lop nhieu lop
x1, y1 = make_blobs(n_samples = 1000, centers = 3, random_state = 1)
print(x1.shape, y1.shape)
# Out:
# (1000, 2) (1000,)

# %%
count = Counter(y1)
count
# Out:
# Counter({0: 334, 1: 333, 2: 333})

# %%
for i in range(10):
    print(x1[i], ',', y1[i])
# Out:
# [-3.05837272  4.48825769] , 0
# [-8.60973869 -3.72714879] , 1
# [1.37129721 5.23107449] , 0
# [-9.33917563 -2.9544469 ] , 1
# [-8.63895561 -8.05263469] , 2
# [-8.48974309 -9.05667083] , 2
# [-7.51235546 -7.96464519] , 2
# [-7.51320529 -7.46053919] , 2
# [-0.61947075  3.48804983] , 0
# [-10.91115591  -4.5772537 ] , 1

# %%
for label, _ in count.items():
    row_ix = where(y1 == label)[0]
    plt.scatter(x1[row_ix,0], x1[row_ix, 1], label = str(label))
plt.legend()
plt.show()

# %%
#phan loai nhi phan ko can bang
#su dung make_classification de tao du lieu
from sklearn.datasets import make_classification as mc
x2, y2 = mc(n_samples = 1000, n_features = 2, n_informative = 2, n_redundant = 0, n_classes = 2, n_clusters_per_class = 1, weights= [0.99, 0.01], random_state = 1)
print(x2.shape, y2.shape) #2lop - 2 dac trung
count1 = Counter(y2)
count1
# Out:
# (1000, 2) (1000,)
# Counter({0: 983, 1: 17})

# %%
for i in range(10):
    print(x2[i], ',', y2[i])
# Out:
# [0.86924745 1.18613612] , 0
# [1.55110839 1.81032905] , 0
# [1.29361936 1.01094607] , 0
# [1.11988947 1.63251786] , 0
# [1.04235568 1.12152929] , 0
# [1.18114858 0.92397607] , 0
# [1.1365562  1.17652556] , 0
# [0.46291729 0.72924998] , 0
# [0.18315826 1.07141766] , 0
# [0.32411648 0.53515376] , 0

# %%
for label, _ in count1.items():
    row_ix = where(y1 == label)[0]
    plt.scatter(x2[row_ix,0], x2[row_ix, 1], label = str(label))
plt.legend()
plt.show()

# %%
# Ví dụ về nhiệm vụ phân loại nhị phân không cân bằng
from numpy import where
from collections import Counter
from sklearn.datasets import make_classification
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_classes=2, n_clusters_per_class=1, weights=[0.99,0.01], random_state=1)
# summarize dataset shape
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# (1000, 2) (1000,)
# Counter({0: 983, 1: 17})
# [0.86924745 1.18613612] 0
# [1.55110839 1.81032905] 0
# [1.29361936 1.01094607] 0
# [1.11988947 1.63251786] 0
# [1.04235568 1.12152929] 0
# [1.18114858 0.92397607] 0
# [1.1365562  1.17652556] 0
# [0.46291729 0.72924998] 0
# [0.18315826 1.07141766] 0
# [0.32411648 0.53515376] 0
